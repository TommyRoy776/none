# %%
import networkx as nx
G=nx.Graph()
G.add_node(1,pos=(1,1))
G.add_node(2,pos=(1,2))
G.add_node(3,pos=(2,1))
G.add_node(4,pos=(2,2))
G.add_node(5,pos=(1.5,1.5))
G.add_node(6,pos=(1.5,2.5))
G.add_node(7,pos=(1.5,0.5))
G.add_node(8,pos=(2.5,1.5))
G.add_node(9,pos=(3,1.5))
G.add_node(10,pos=(3.5,1.5))
G.add_edge(1,2)
G.add_edge(3,4)
G.add_edge(3,4)
G.add_edge(2,3)
G.add_edge(1,4)
G.add_edge(6,7)
G.add_edge(4,8)
G.add_edge(3,8)
G.add_edge(1,3)
G.add_edge(2,4)
G.add_edge(2,6)
G.add_edge(6,4)
G.add_edge(1,7)
G.add_edge(7,3)
G.add_edge(8,10)
pos=nx.get_node_attributes(G,'pos')
nx.draw(G,pos,with_labels = True)
